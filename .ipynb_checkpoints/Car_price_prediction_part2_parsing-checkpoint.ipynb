# %%
# !pip install loguru
# Out:
# Collecting loguru
#   Downloading loguru-0.5.3-py3-none-any.whl (57 kB)
# Requirement already satisfied: colorama>=0.3.4; sys_platform == "win32" in c:\users\user-pc\anaconda3\lib\site-packages (from loguru) (0.4.3)
# Collecting win32-setctime>=1.0.0; sys_platform == "win32"
#   Downloading win32_setctime-1.0.3-py3-none-any.whl (3.5 kB)
# Installing collected packages: win32-setctime, loguru
# Successfully installed loguru-0.5.3 win32-setctime-1.0.3

# %%
import argparse
from collections import namedtuple, defaultdict
from csv import DictWriter
import json
from pathlib import Path

import requests
from loguru import logger

# %%
columns = ['bodyType', 'brand', 'car_url', 'color', 'complectation_dict', 'description', 'engineDisplacement',
           'enginePower', 'location',
           'equipment_dict', 'fuelType', 'image', 'mileage', 'modelDate', 'model_info', 'model_name', 'name',
           'numberOfDoors', 'parsing_unixtime', 'priceCurrency', 'productionDate', 'sell_id', 'super_gen',
           'vehicleConfiguration', 'vehicleTransmission', 'vendor', 'Владельцы', 'Владение', 'ПТС', 'Привод',
           'Руль', 'Состояние', 'Таможня', 'price']

# %%
CarInfo = namedtuple('Car', columns)

# %%
brand_in_test = {
    'BMW': 4473,
    'VOLKSWAGEN': 4404,
    'NISSAN': 4393,
    'MERCEDES': 4180,
    'TOYOTA': 3913,
    'AUDI': 3421,
    'MITSUBISHI': 2843,
    'SKODA': 2741,
    'VOLVO': 1463,
    'HONDA': 1150,
    'INFINITI': 871,
    'LEXUS': 834
}

# %%
cars_in_test = sum(val for val in brand_in_test.values())
print(cars_in_test)
# Out:
# 34686

# %%
proportion_in_test = {key: val / cars_in_test for key, val in brand_in_test.items()}
print(proportion_in_test)
# Out:
# {'BMW': 0.12895692786715102, 'VOLKSWAGEN': 0.12696765265524995, 'NISSAN': 0.12665052182436717, 'MERCEDES': 0.12050971573545523, 'TOYOTA': 0.11281208556766419, 'AUDI': 0.09862768840454363, 'MITSUBISHI': 0.08196390474543043, 'SKODA': 0.07902323704088104, 'VOLVO': 0.04217840050740933, 'HONDA': 0.033154586865017585, 'INFINITI': 0.02511099579080897, 'LEXUS': 0.02404428299602145}

# %%
def get_headers():
    headers = '''
Host: auto.ru
Connection: keep-alive
Content-Length: 99
x-requested-with: fetch
x-client-date: 1603066469874
x-csrf-token: c23073bb4cd65413662a41bd460fd8317459fe3ce6d83db1
x-page-request-id: 3c4800b60eb9e8c568e5a515f5cd4872
content-type: application/json
User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36
x-client-app-version: 202010.16.122434
Accept: */*
Origin: https://auto.ru
Sec-Fetch-Site: same-origin
Sec-Fetch-Mode: same-origin
Sec-Fetch-Dest: empty
Referer: https://auto.ru/cars/bmw/all/?output_type=list&page=1
Accept-Encoding: gzip, deflate, br
Accept-Language: ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7
Cookie: autoru_sid=a%3Ag5f88f7d72b1bif6t0m99h0krigjgs2e.a783a85b576c8a7acaea4faafaa81ffc%7C1602811863959.604800.QhhqH0HWfM4BPWrsvjyfIg.8EXrpUR7Bq1a2gOSCnsb0HnXxvmHbYB9eF5Uz5o_bZE; autoruuid=g5f88f7d72b1bif6t0m99h0krigjgs2e.a783a85b576c8a7acaea4faafaa81ffc; suid=63abf8672f4a9e550bb96dd00b95ad21.8e155bfb838a5227bdd9dea1d2cbdc3e; _ym_uid=1602811867719278329; yuidcs=1; crookie=PZwS3/iYq2PFIw/dbrsqDVB/0e2v79Xe/8RsG6ySC8Djcl+mh/UCjYohgODaSkw7rMa6O9v7+RD56YSQKE2fhSkWxV8=; cmtchd=MTYwMjgyODMxMjMwNQ==; bltsr=1; yuidlt=1; yandexuid=360949521578055883; my=YwA%3D; _ym_isad=1; promo-app-banner-shown=1; promo-header-counter=4; _csrf_token=c23073bb4cd65413662a41bd460fd8317459fe3ce6d83db1; from=direct; X-Vertis-DC=myt; _ym_wasSynced=%7B%22time%22%3A1603066366683%2C%22params%22%3A%7B%22eu%22%3A0%7D%2C%22bkParams%22%3A%7B%7D%7D; gdpr=0; _ym_visorc_22753222=b; from_lifetime=1603066463083; _ym_d=1603066470'''
    headers = {line.split(': ')[0]: line.split(': ')[1] for line in headers.strip().split('\n')}
    return headers

# %%
def get_data_from_site(pange_num: int, brand: str) -> dict:
    """ получает данные о тачках БМВ с авто.ру, номер страницы передан в параметре page_num
    возвращает полученный с сайта json """

    base_url = 'https://auto.ru/-/ajax/desktop/listing/'
    params = dict(category='cars', section="all", output_type="list", page=pange_num,
                  catalog_filter=[{'mark': brand}], geo_id=[213], geo_radius=800)
    r = requests.post(base_url, json=params, headers=get_headers())
    r.raise_for_status()
    return r.json()

# %%
try:
    get_data_from_site(1,'BMW')['offers'][0]['documents']['purchase_date']
except KeyError:
    purchase_date = None

# %%
def add_car_data(car_data: list, data_json: dict):
    """ разбирает данные из переданного объекта data_json
    из массива offers, формирует объекты CarInfo и
    добавляет их в список car_data"""

    if 'offers' not in data_json:
        return 

    for car in data_json['offers']:
        if 'configuration' not in car['vehicle_info']:
            continue

        body_type_human = car['vehicle_info']['configuration']['human_name']
        body_type = car['vehicle_info']['configuration']['body_type']
        transmission = car['vehicle_info']['tech_param']['transmission']
        engine_volume = car['vehicle_info']['tech_param']['displacement']
        engine_volume = round(float(engine_volume) / 1000, 1)

        try:
            purchase_date = car['documents']['purchase_date']
        except KeyError:
            purchase_date = None

        try:
            owners_number = car['documents']['owners_number']
        except KeyError:
            owners_number = None

        try:
            description = car['description']
        except KeyError:
            description = None
        try:
            pts = car['documents']['pts']
        except KeyError:
            pts = None
        try:
            price = car['price_info']['RUR']
        except KeyError:
            continue

        brand = car['vehicle_info']['mark_info']['name']
        model = car['vehicle_info']['model_info']['name']
        sell_id = car['saleId']
        section = car['section']
        car_url = f'https://auto.ru/cars/{section}/sale/{brand.lower()}/{model.lower()}/{sell_id}/'

        info = CarInfo(bodyType=body_type_human,
                       brand=brand,
                       car_url=car_url,
                       image=car['state']['image_urls'][0]['sizes']['small'],
                       color=car['color_hex'],
                       complectation_dict=car['vehicle_info']['complectation'],
                       equipment_dict=car['vehicle_info']['equipment'],
                       model_info=car['vehicle_info']['model_info'],
                       model_name=model,
                       location=car['seller']['location']['region_info']['name'],
                       parsing_unixtime=car['additional_info']['fresh_date'],
                       priceCurrency=car['price_info']['currency'],
                       sell_id=sell_id,
                       super_gen=car['vehicle_info']['super_gen'],
                       vendor=car['vehicle_info']['vendor'],
                       fuelType=car['vehicle_info']['tech_param']['engine_type'],
                       modelDate=car['vehicle_info']['super_gen']['year_from'],
                       name=car['vehicle_info']['tech_param']['human_name'],
                       numberOfDoors=car['vehicle_info']['configuration']['doors_count'],
                       productionDate=car['documents']['year'],
                       vehicleConfiguration=body_type + " " + transmission + " " + str(engine_volume),
                       vehicleTransmission=transmission,
                       engineDisplacement=str(engine_volume) + ' LTR',
                       enginePower=str(car['vehicle_info']['tech_param']['power']) + ' N12',
                       description=description,
                       mileage=car['state']['mileage'],
                       Привод=car['vehicle_info']['tech_param']['gear_type'],
                       Руль=car['vehicle_info']['steering_wheel'],
                       Состояние=car['state']['state_not_beaten'],
                       Владельцы=owners_number,
                       ПТС=pts,
                       Таможня=car['documents']['custom_cleared'],
                       Владение=purchase_date,
                       price=price
                       )
        car_data.append(info)

# %%
def write_to_csv(car_data: list, output_folder_path: Path, page_num: int):
    """Записывает информацию о машинах из car_data в файл формата csv
    output_folder_path задает папку для сохранения
    page_num - нужен для наименования файла"""

    if not car_data:
        return

    filename = output_folder_path / f'train_{page_num}.csv'
    with open(filename, 'w', encoding='utf-8', newline='') as f:
        logger.info(f'writing {filename}, содержащий {len(car_data)} записей')
        writer = DictWriter(f, fieldnames=columns)
        writer.writeheader()
        writer.writerows([car._asdict() for car in car_data])

# %%
def pickup_brand(brand_stats: dict) -> str:
    cars_count = sum(val for val in brand_stats.values())
    brand_proportion = {key: val / cars_count for key, val in brand_stats.items()}

    proportion_in_test_copy = proportion_in_test.copy()
    for key, val in brand_proportion.items():
        proportion_in_test_copy[key] -= val

    return sorted(proportion_in_test_copy.items(),
                  key=lambda x: x[1],
                  reverse=True)[0][0] # first element, key of pair key:value

# %%
def parse_data(n_pages, output_folder, save_json, json_folder):
    """Входная точка в программу. Содержит верхнеуровневую логику.
    Собирает информацию с сайта, парсит и сохраняет в формате csv"""

    logger.info('Starting parse data from auto.ru about cars')

    if save_json:
        json_folder_path = Path(json_folder)
        json_folder_path.mkdir(parents=True, exist_ok=True)

    output_folder_path = Path(output_folder)
    output_folder_path.mkdir(parents=True, exist_ok=True)

    car_data = []
    brand_stats = defaultdict(lambda: 1)

    for page_num in range(1, n_pages + 1):

        brand = pickup_brand(brand_stats)

        logger.info(f'processing page: {page_num} {brand} {brand_stats[brand]}')
        try:
            data_json = get_data_from_site(brand_stats[brand], brand)
        except Exception as e:
            logger.error(f"Error in parsing: {e}")
            continue

        brand_stats[brand] += 1

        if save_json:
            with open(json_folder_path / f'page_{page_num}.json', 'w', encoding='utf-8') as f:
                json.dump(data_json, f)

        add_car_data(car_data, data_json)

        if page_num % 50 == 0:
            write_to_csv(car_data, output_folder_path, page_num)
            car_data = []

    write_to_csv(car_data, output_folder_path, page_num)

    logger.info('parsing successfully finished')

# %%
def main():
    parser = argparse.ArgumentParser()
    parser.add_argument("n_pages", help="number of pages to parse", type=int)
    parser.add_argument("-o", "-train_folder", help='folder to save parsed csv files', type=str, default='.')
    parser.add_argument("-j", "--save_json", help="save json files", action="store_true")
    parser.add_argument("--json_folder", help='folder for json files', type=str, default='json')
    args = parser.parse_args()
    print(args)
    ##parse_data(args.n_pages,
    #           args.output_folder,
    #           args.save_json,
    #           args.json_folder)

# %%
if __name__ == '__main__':
    main()
# Out:
# usage: ipykernel_launcher.py [-h] [-o O] [-j] [--json_folder JSON_FOLDER] n_pages
# ipykernel_launcher.py: error: argument n_pages: invalid int value: 'C:\\Users\\User-PC\\AppData\\Roaming\\jupyter\\runtime\\kernel-0674999f-5e03-4dbe-ba45-b670ca61e533.json'
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\User-PC\anaconda3\lib\argparse.py", line 2422, in _get_value
#     result = type_func(arg_string)
# ValueError: invalid literal for int() with base 10: 'C:\\Users\\User-PC\\AppData\\Roaming\\jupyter\\runtime\\kernel-0674999f-5e03-4dbe-ba45-b670ca61e533.json'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\User-PC\anaconda3\lib\argparse.py", line 1800, in parse_known_args
#     namespace, args = self._parse_known_args(args, namespace)
#   File "C:\Users\User-PC\anaconda3\lib\argparse.py", line 2009, in _parse_known_args
#     stop_index = consume_positionals(start_index)
#   File "C:\Users\User-PC\anaconda3\lib\argparse.py", line 1965, in consume_positionals
#     take_action(action, args)
#   File "C:\Users\User-PC\anaconda3\lib\argparse.py", line 1858, in take_action
#     argument_values = self._get_values(action, argument_strings)
#   File "C:\Users\User-PC\anaconda3\lib\argparse.py", line 2389, in _get_values
#     value = self._get_value(action, arg_string)
#   File "C:\Users\User-PC\anaconda3\lib\argparse.py", line 2435, in _get_value
#     raise ArgumentError(action, msg % args)
# argparse.ArgumentError: argument n_pages: invalid int value: 'C:\\Users\\User-PC\\AppData\\Roaming\\jupyter\\runtime\\kernel-0674999f-5e03-4dbe-ba45-b670ca61e533.json'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\User-PC\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-46-c7bc734e5e35>", line 2, in <module>
#     main()
#   File "<ipython-input-45-90774567693f>", line 7, in main
#     args = parser.parse_args()
#   File "C:\Users\User-PC\anaconda3\lib\argparse.py", line 1768, in parse_args
#     args, argv = self.parse_known_args(args, namespace)
#   File "C:\Users\User-PC\anaconda3\lib\argparse.py", line 1807, in parse_known_args
#     self.error(str(err))
#   File "C:\Users\User-PC\anaconda3\lib\argparse.py", line 2521, in error
#     self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#   File "C:\Users\User-PC\anaconda3\lib\argparse.py", line 2508, in exit
#     _sys.exit(status)
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\User-PC\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\User-PC\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\User-PC\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\User-PC\anaconda3\lib\inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\argparse.py in _get_value(self, action, arg_string)
#    2421         try:
# -> 2422             result = type_func(arg_string)
#    2423
#
# ValueError: invalid literal for int() with base 10: 'C:\\Users\\User-PC\\AppData\\Roaming\\jupyter\\runtime\\kernel-0674999f-5e03-4dbe-ba45-b670ca61e533.json'
#
# During handling of the above exception, another exception occurred:
#
# ArgumentError                             Traceback (most recent call last)
# ~\anaconda3\lib\argparse.py in parse_known_args(self, args, namespace)
#    1799         try:
# -> 1800             namespace, args = self._parse_known_args(args, namespace)
#    1801             if hasattr(namespace, _UNRECOGNIZED_ARGS_ATTR):
#
# ~\anaconda3\lib\argparse.py in _parse_known_args(self, arg_strings, namespace)
#    2008         # consume any positionals following the last Optional
# -> 2009         stop_index = consume_positionals(start_index)
#    2010
#
# ~\anaconda3\lib\argparse.py in consume_positionals(start_index)
#    1964                 start_index += arg_count
# -> 1965                 take_action(action, args)
#    1966
#
# ~\anaconda3\lib\argparse.py in take_action(action, argument_strings, option_string)
#    1857             seen_actions.add(action)
# -> 1858             argument_values = self._get_values(action, argument_strings)
#    1859
#
# ~\anaconda3\lib\argparse.py in _get_values(self, action, arg_strings)
#    2388             arg_string, = arg_strings
# -> 2389             value = self._get_value(action, arg_string)
#    2390             self._check_value(action, value)
#
# ~\anaconda3\lib\argparse.py in _get_value(self, action, arg_string)
#    2434             msg = _('invalid %(type)s value: %(value)r')
# -> 2435             raise ArgumentError(action, msg % args)
#    2436
#
# ArgumentError: argument n_pages: invalid int value: 'C:\\Users\\User-PC\\AppData\\Roaming\\jupyter\\runtime\\kernel-0674999f-5e03-4dbe-ba45-b670ca61e533.json'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-46-c7bc734e5e35> in <module>
#       1 if __name__ == '__main__':
# ----> 2     main()
#
# <ipython-input-45-90774567693f> in main()
#       6     parser.add_argument("--json_folder", help='folder for json files', type=str, default='json')
# ----> 7     args = parser.parse_args()
#       8     print(args)
#
# ~\anaconda3\lib\argparse.py in parse_args(self, args, namespace)
#    1767     def parse_args(self, args=None, namespace=None):
# -> 1768         args, argv = self.parse_known_args(args, namespace)
#    1769         if argv:
#
# ~\anaconda3\lib\argparse.py in parse_known_args(self, args, namespace)
#    1806             err = _sys.exc_info()[1]
# -> 1807             self.error(str(err))
#    1808
#
# ~\anaconda3\lib\argparse.py in error(self, message)
#    2520         args = {'prog': self.prog, 'message': message}
# -> 2521         self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# ~\anaconda3\lib\argparse.py in exit(self, status, message)
#    2507             self._print_message(message, _sys.stderr)
# -> 2508         _sys.exit(status)
#    2509
#
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2035                     stb = ['An exception has occurred, use %tb to see '
#    2036                            'the full traceback.\n']
# -> 2037                     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2038                                                                      value))
#    2039                 else:
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in get_exception_only(self, etype, value)
#     821         value : exception value
#     822         """
# --> 823         return ListTB.structured_traceback(self, etype, value)
#     824
#     825     def show_exception_only(self, etype, evalue):
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     696             chained_exceptions_tb_offset = 0
#     697             out_list = (
# --> 698                 self.structured_traceback(
#     699                     etype, evalue, (etb, chained_exc_ids),
#     700                     chained_exceptions_tb_offset, context)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1433         else:
#    1434             self.tb = tb
# -> 1435         return FormattedTB.structured_traceback(
#    1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1333         if mode in self.verbose_modes:
#    1334             # Verbose modes need a full traceback
# -> 1335             return VerboseTB.structured_traceback(
#    1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1190         """Return a nice text document describing the traceback."""
#    1191
# -> 1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1193                                                                tb_offset)
#    1194
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~\anaconda3\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
parse_data(2000,'train_folder',1,'json_folder')
# Out:
# 2021-03-06 12:37:01.195 | INFO     | __main__:parse_data:5 - Starting parse data from auto.ru about cars
# 2021-03-06 12:37:01.196 | INFO     | __main__:parse_data:21 - processing page: 1 BMW 1
# 2021-03-06 12:37:01.837 | INFO     | __main__:parse_data:21 - processing page: 2 VOLKSWAGEN 1
# 2021-03-06 12:37:02.350 | INFO     | __main__:parse_data:21 - processing page: 3 NISSAN 1
# 2021-03-06 12:37:03.023 | INFO     | __main__:parse_data:21 - processing page: 4 MERCEDES 1
# 2021-03-06 12:37:03.523 | INFO     | __main__:parse_data:21 - processing page: 5 TOYOTA 1
# 2021-03-06 12:37:04.275 | INFO     | __main__:parse_data:21 - processing page: 6 AUDI 1
# 2021-03-06 12:37:04.973 | INFO     | __main__:parse_data:21 - processing page: 7 MITSUBISHI 1
# 2021-03-06 12:37:05.596 | INFO     | __main__:parse_data:21 - processing page: 8 SKODA 1
# 2021-03-06 12:37:06.213 | INFO     | __main__:parse_data:21 - processing page: 9 VOLVO 1
# 2021-03-06 12:37:06.812 | INFO     | __main__:parse_data:21 - processing page: 10 HONDA 1
# 2021-03-06 12:37:07.374 | INFO     | __main__:parse_data:21 - processing page: 11 BMW 2
# 2021-03-06 12:37:08.002 | INFO     | __main__:parse_data:21 - processing page: 12 VOLKSWAGEN 2
# 2021-03-06 12:37:08.596 | INFO     | __main__:parse_data:21 - processing page: 13 NISSAN 2
# 2021-03-06 12:37:09.101 | INFO     | __main__:parse_data:21 - processing page: 14 MERCEDES 2
# 2021-03-06 12:37:09.845 | INFO     | __main__:parse_data:21 - processing page: 15 TOYOTA 2
# 2021-03-06 12:37:10.721 | INFO     | __main__:parse_data:21 - processing page: 16 INFINITI 1
# 2021-03-06 12:37:11.373 | INFO     | __main__:parse_data:21 - processing page: 17 AUDI 2
# 2021-03-06 12:37:12.114 | INFO     | __main__:parse_data:21 - processing page: 18 LEXUS 1
# 2021-03-06 12:37:12.680 | INFO     | __main__:parse_data:21 - processing page: 19 BMW 3
# 2021-03-06 12:37:13.368 | INFO     | __main__:parse_data:21 - processing page: 20 VOLKSWAGEN 3
# 2021-03-06 12:37:14.123 | INFO     | __main__:parse_data:21 - processing page: 21 NISSAN 3
# 2021-03-06 12:37:14.751 | INFO     | __main__:parse_data:21 - processing page: 22 MERCEDES 3
# 2021-03-06 12:37:15.304 | INFO     | __main__:parse_data:21 - processing page: 23 TOYOTA 3
# 2021-03-06 12:37:15.946 | INFO     | __main__:parse_data:21 - processing page: 24 MITSUBISHI 2
# 2021-03-06 12:37:16.418 | INFO     | __main__:parse_data:21 - processing page: 25 SKODA 2
# 2021-03-06 12:37:17.113 | INFO     | __main__:parse_data:21 - processing page: 26 BMW 4
# 2021-03-06 12:37:17.837 | INFO     | __main__:parse_data:21 - processing page: 27 VOLKSWAGEN 4
# 2021-03-06 12:37:18.358 | INFO     | __main__:parse_data:21 - processing page: 28 NISSAN 4
# 2021-03-06 12:37:18.963 | INFO     | __main__:parse_data:21 - processing page: 29 AUDI 3
# 2021-03-06 12:37:19.672 | INFO     | __main__:parse_data:21 - processing page: 30 MERCEDES 4
# 2021-03-06 12:37:20.351 | INFO     | __main__:parse_data:21 - processing page: 31 TOYOTA 4
# 2021-03-06 12:37:20.909 | INFO     | __main__:parse_data:21 - processing page: 32 BMW 5
# 2021-03-06 12:37:21.551 | INFO     | __main__:parse_data:21 - processing page: 33 MITSUBISHI 3
# 2021-03-06 12:37:22.211 | INFO     | __main__:parse_data:21 - processing page: 34 VOLKSWAGEN 5
# 2021-03-06 12:37:22.734 | INFO     | __main__:parse_data:21 - processing page: 35 NISSAN 5
# 2021-03-06 12:37:23.430 | INFO     | __main__:parse_data:21 - processing page: 36 SKODA 3
# 2021-03-06 12:37:23.957 | INFO     | __main__:parse_data:21 - processing page: 37 MERCEDES 5
# 2021-03-06 12:37:24.559 | INFO     | __main__:parse_data:21 - processing page: 38 AUDI 4
# 2021-03-06 12:37:26.054 | INFO     | __main__:parse_data:21 - processing page: 39 TOYOTA 5
# 2021-03-06 12:37:26.707 | INFO     | __main__:parse_data:21 - processing page: 40 BMW 6
# 2021-03-06 12:37:27.355 | INFO     | __main__:parse_data:21 - processing page: 41 VOLKSWAGEN 6
# 2021-03-06 12:37:28.075 | INFO     | __main__:parse_data:21 - processing page: 42 NISSAN 6
# 2021-03-06 12:37:28.575 | INFO     | __main__:parse_data:21 - processing page: 43 MERCEDES 6
# 2021-03-06 12:37:29.306 | INFO     | __main__:parse_data:21 - processing page: 44 MITSUBISHI 4
# 2021-03-06 12:37:29.872 | INFO     | __main__:parse_data:21 - processing page: 45 AUDI 5
# 2021-03-06 12:37:30.537 | INFO     | __main__:parse_data:21 - processing page: 46 SKODA 4
# 2021-03-06 12:37:31.125 | INFO     | __main__:parse_data:21 - processing page: 47 TOYOTA 6
# 2021-03-06 12:37:31.693 | INFO     | __main__:parse_data:21 - processing page: 48 BMW 7
# 2021-03-06 12:37:32.293 | INFO     | __main__:parse_data:21 - processing page: 49 VOLKSWAGEN 7
# 2021-03-06 12:37:32.775 | INFO     | __main__:parse_data:21 - processing page: 50 NISSAN 7
# 2021-03-06 12:37:33.441 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_50.csv, содержащий 1850 записей
# 2021-03-06 12:37:33.756 | INFO     | __main__:parse_data:21 - processing page: 51 VOLVO 2
# 2021-03-06 12:37:34.268 | INFO     | __main__:parse_data:21 - processing page: 52 MERCEDES 7
# 2021-03-06 12:37:34.812 | INFO     | __main__:parse_data:21 - processing page: 53 AUDI 6
# 2021-03-06 12:37:35.447 | INFO     | __main__:parse_data:21 - processing page: 54 BMW 8
# 2021-03-06 12:37:36.111 | INFO     | __main__:parse_data:21 - processing page: 55 TOYOTA 7
# 2021-03-06 12:37:36.803 | INFO     | __main__:parse_data:21 - processing page: 56 VOLKSWAGEN 8
# 2021-03-06 12:37:37.311 | INFO     | __main__:parse_data:21 - processing page: 57 NISSAN 8
# 2021-03-06 12:37:37.856 | INFO     | __main__:parse_data:21 - processing page: 58 MITSUBISHI 5
# 2021-03-06 12:37:38.453 | INFO     | __main__:parse_data:21 - processing page: 59 SKODA 5
# 2021-03-06 12:37:39.050 | INFO     | __main__:parse_data:21 - processing page: 60 MERCEDES 8
# 2021-03-06 12:37:39.646 | INFO     | __main__:parse_data:21 - processing page: 61 HONDA 2
# 2021-03-06 12:37:40.167 | INFO     | __main__:parse_data:21 - processing page: 62 BMW 9
# 2021-03-06 12:37:40.832 | INFO     | __main__:parse_data:21 - processing page: 63 VOLKSWAGEN 9
# 2021-03-06 12:37:41.343 | INFO     | __main__:parse_data:21 - processing page: 64 NISSAN 9
# 2021-03-06 12:37:41.958 | INFO     | __main__:parse_data:21 - processing page: 65 TOYOTA 8
# 2021-03-06 12:37:42.471 | INFO     | __main__:parse_data:21 - processing page: 66 AUDI 7
# 2021-03-06 12:37:43.103 | INFO     | __main__:parse_data:21 - processing page: 67 MERCEDES 9
# 2021-03-06 12:37:43.897 | INFO     | __main__:parse_data:21 - processing page: 68 MITSUBISHI 6
# 2021-03-06 12:37:44.596 | INFO     | __main__:parse_data:21 - processing page: 69 VOLVO 3
# 2021-03-06 12:37:45.173 | INFO     | __main__:parse_data:21 - processing page: 70 BMW 10
# 2021-03-06 12:37:45.953 | INFO     | __main__:parse_data:21 - processing page: 71 SKODA 6
# 2021-03-06 12:37:46.449 | INFO     | __main__:parse_data:21 - processing page: 72 VOLKSWAGEN 10
# 2021-03-06 12:37:47.017 | INFO     | __main__:parse_data:21 - processing page: 73 NISSAN 10
# 2021-03-06 12:37:47.646 | INFO     | __main__:parse_data:21 - processing page: 74 TOYOTA 9
# 2021-03-06 12:37:48.429 | INFO     | __main__:parse_data:21 - processing page: 75 AUDI 8
# 2021-03-06 12:37:49.095 | INFO     | __main__:parse_data:21 - processing page: 76 MERCEDES 10
# 2021-03-06 12:37:49.645 | INFO     | __main__:parse_data:21 - processing page: 77 BMW 11
# 2021-03-06 12:37:50.236 | INFO     | __main__:parse_data:21 - processing page: 78 VOLKSWAGEN 11
# 2021-03-06 12:37:50.718 | INFO     | __main__:parse_data:21 - processing page: 79 NISSAN 11
# 2021-03-06 12:37:51.283 | INFO     | __main__:parse_data:21 - processing page: 80 MITSUBISHI 7
# 2021-03-06 12:37:51.901 | INFO     | __main__:parse_data:21 - processing page: 81 TOYOTA 10
# 2021-03-06 12:37:52.488 | INFO     | __main__:parse_data:21 - processing page: 82 SKODA 7
# 2021-03-06 12:37:53.039 | INFO     | __main__:parse_data:21 - processing page: 83 INFINITI 2
# 2021-03-06 12:37:53.581 | INFO     | __main__:parse_data:21 - processing page: 84 MERCEDES 11
# 2021-03-06 12:37:54.263 | INFO     | __main__:parse_data:21 - processing page: 85 AUDI 9
# 2021-03-06 12:37:55.003 | INFO     | __main__:parse_data:21 - processing page: 86 BMW 12
# 2021-03-06 12:37:55.693 | INFO     | __main__:parse_data:21 - processing page: 87 VOLKSWAGEN 12
# 2021-03-06 12:37:56.281 | INFO     | __main__:parse_data:21 - processing page: 88 NISSAN 12
# 2021-03-06 12:37:56.905 | INFO     | __main__:parse_data:21 - processing page: 89 LEXUS 2
# 2021-03-06 12:37:57.730 | INFO     | __main__:parse_data:21 - processing page: 90 TOYOTA 11
# 2021-03-06 12:37:58.462 | INFO     | __main__:parse_data:21 - processing page: 91 HONDA 3
# 2021-03-06 12:37:58.994 | INFO     | __main__:parse_data:21 - processing page: 92 MITSUBISHI 8
# 2021-03-06 12:37:59.552 | INFO     | __main__:parse_data:21 - processing page: 93 MERCEDES 12
# 2021-03-06 12:38:00.108 | INFO     | __main__:parse_data:21 - processing page: 94 BMW 13
# 2021-03-06 12:38:00.740 | INFO     | __main__:parse_data:21 - processing page: 95 VOLVO 4
# 2021-03-06 12:38:01.499 | INFO     | __main__:parse_data:21 - processing page: 96 VOLKSWAGEN 13
# 2021-03-06 12:38:02.019 | INFO     | __main__:parse_data:21 - processing page: 97 NISSAN 13
# 2021-03-06 12:38:02.680 | INFO     | __main__:parse_data:21 - processing page: 98 AUDI 10
# 2021-03-06 12:38:03.257 | INFO     | __main__:parse_data:21 - processing page: 99 SKODA 8
# 2021-03-06 12:38:03.900 | INFO     | __main__:parse_data:21 - processing page: 100 TOYOTA 12
# 2021-03-06 12:38:04.500 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_100.csv, содержащий 1850 записей
# 2021-03-06 12:38:04.813 | INFO     | __main__:parse_data:21 - processing page: 101 MERCEDES 13
# 2021-03-06 12:38:05.762 | INFO     | __main__:parse_data:21 - processing page: 102 BMW 14
# 2021-03-06 12:38:06.539 | INFO     | __main__:parse_data:21 - processing page: 103 VOLKSWAGEN 14
# 2021-03-06 12:38:07.260 | INFO     | __main__:parse_data:21 - processing page: 104 NISSAN 14
# 2021-03-06 12:38:07.794 | INFO     | __main__:parse_data:21 - processing page: 105 MITSUBISHI 9
# 2021-03-06 12:38:08.425 | INFO     | __main__:parse_data:21 - processing page: 106 AUDI 11
# 2021-03-06 12:38:09.123 | INFO     | __main__:parse_data:21 - processing page: 107 SKODA 9
# 2021-03-06 12:38:09.631 | INFO     | __main__:parse_data:21 - processing page: 108 TOYOTA 13
# 2021-03-06 12:38:10.277 | INFO     | __main__:parse_data:21 - processing page: 109 BMW 15
# 2021-03-06 12:38:10.880 | INFO     | __main__:parse_data:21 - processing page: 110 MERCEDES 14
# 2021-03-06 12:38:11.457 | INFO     | __main__:parse_data:21 - processing page: 111 VOLKSWAGEN 15
# 2021-03-06 12:38:12.106 | INFO     | __main__:parse_data:21 - processing page: 112 NISSAN 15
# 2021-03-06 12:38:12.864 | INFO     | __main__:parse_data:21 - processing page: 113 VOLVO 5
# 2021-03-06 12:38:13.709 | INFO     | __main__:parse_data:21 - processing page: 114 AUDI 12
# 2021-03-06 12:38:14.362 | INFO     | __main__:parse_data:21 - processing page: 115 MITSUBISHI 10
# 2021-03-06 12:38:14.997 | INFO     | __main__:parse_data:21 - processing page: 116 BMW 16
# 2021-03-06 12:38:15.716 | INFO     | __main__:parse_data:21 - processing page: 117 TOYOTA 14
# 2021-03-06 12:38:16.696 | INFO     | __main__:parse_data:21 - processing page: 118 MERCEDES 15
# 2021-03-06 12:38:17.339 | INFO     | __main__:parse_data:21 - processing page: 119 VOLKSWAGEN 16
# 2021-03-06 12:38:17.914 | INFO     | __main__:parse_data:21 - processing page: 120 NISSAN 16
# 2021-03-06 12:38:18.471 | INFO     | __main__:parse_data:21 - processing page: 121 SKODA 10
# 2021-03-06 12:38:18.971 | INFO     | __main__:parse_data:21 - processing page: 122 HONDA 4
# 2021-03-06 12:38:19.567 | INFO     | __main__:parse_data:21 - processing page: 123 INFINITI 3
# 2021-03-06 12:38:20.173 | INFO     | __main__:parse_data:21 - processing page: 124 BMW 17
# 2021-03-06 12:38:20.858 | INFO     | __main__:parse_data:21 - processing page: 125 AUDI 13
# 2021-03-06 12:38:21.535 | INFO     | __main__:parse_data:21 - processing page: 126 MERCEDES 16
# 2021-03-06 12:38:22.226 | INFO     | __main__:parse_data:21 - processing page: 127 TOYOTA 15
# 2021-03-06 12:38:22.962 | INFO     | __main__:parse_data:21 - processing page: 128 VOLKSWAGEN 17
# 2021-03-06 12:38:23.625 | INFO     | __main__:parse_data:21 - processing page: 129 NISSAN 17
# 2021-03-06 12:38:24.266 | INFO     | __main__:parse_data:21 - processing page: 130 MITSUBISHI 11
# 2021-03-06 12:38:24.913 | INFO     | __main__:parse_data:21 - processing page: 131 LEXUS 3
# 2021-03-06 12:38:25.612 | INFO     | __main__:parse_data:21 - processing page: 132 BMW 18
# 2021-03-06 12:38:26.180 | INFO     | __main__:parse_data:21 - processing page: 133 SKODA 11
# 2021-03-06 12:38:26.831 | INFO     | __main__:parse_data:21 - processing page: 134 MERCEDES 17
# 2021-03-06 12:38:27.418 | INFO     | __main__:parse_data:21 - processing page: 135 VOLKSWAGEN 18
# 2021-03-06 12:38:28.116 | INFO     | __main__:parse_data:21 - processing page: 136 NISSAN 18
# 2021-03-06 12:38:28.802 | INFO     | __main__:parse_data:21 - processing page: 137 TOYOTA 16
# 2021-03-06 12:38:29.371 | INFO     | __main__:parse_data:21 - processing page: 138 AUDI 14
# 2021-03-06 12:38:30.181 | INFO     | __main__:parse_data:21 - processing page: 139 BMW 19
# 2021-03-06 12:38:30.900 | INFO     | __main__:parse_data:21 - processing page: 140 MITSUBISHI 12
# 2021-03-06 12:38:31.450 | INFO     | __main__:parse_data:21 - processing page: 141 VOLVO 6
# 2021-03-06 12:38:31.919 | INFO     | __main__:parse_data:21 - processing page: 142 MERCEDES 18
# 2021-03-06 12:38:32.630 | INFO     | __main__:parse_data:21 - processing page: 143 VOLKSWAGEN 19
# 2021-03-06 12:38:33.179 | INFO     | __main__:parse_data:21 - processing page: 144 NISSAN 19
# 2021-03-06 12:38:33.715 | INFO     | __main__:parse_data:21 - processing page: 145 TOYOTA 17
# 2021-03-06 12:38:34.261 | INFO     | __main__:parse_data:21 - processing page: 146 AUDI 15
# 2021-03-06 12:38:34.864 | INFO     | __main__:parse_data:21 - processing page: 147 SKODA 12
# 2021-03-06 12:38:35.433 | INFO     | __main__:parse_data:21 - processing page: 148 BMW 20
# 2021-03-06 12:38:36.165 | INFO     | __main__:parse_data:21 - processing page: 149 VOLKSWAGEN 20
# 2021-03-06 12:38:36.791 | INFO     | __main__:parse_data:21 - processing page: 150 MERCEDES 19
# 2021-03-06 12:38:37.496 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_150.csv, содержащий 1850 записей
# 2021-03-06 12:38:37.790 | INFO     | __main__:parse_data:21 - processing page: 151 NISSAN 20
# 2021-03-06 12:38:38.365 | INFO     | __main__:parse_data:21 - processing page: 152 HONDA 5
# 2021-03-06 12:38:38.792 | INFO     | __main__:parse_data:21 - processing page: 153 TOYOTA 18
# 2021-03-06 12:38:39.326 | INFO     | __main__:parse_data:21 - processing page: 154 MITSUBISHI 13
# 2021-03-06 12:38:39.741 | INFO     | __main__:parse_data:21 - processing page: 155 BMW 21
# 2021-03-06 12:38:40.387 | INFO     | __main__:parse_data:21 - processing page: 156 AUDI 16
# 2021-03-06 12:38:41.028 | INFO     | __main__:parse_data:21 - processing page: 157 VOLKSWAGEN 21
# 2021-03-06 12:38:41.702 | INFO     | __main__:parse_data:21 - processing page: 158 NISSAN 21
# 2021-03-06 12:38:42.281 | INFO     | __main__:parse_data:21 - processing page: 159 MERCEDES 20
# 2021-03-06 12:38:42.933 | INFO     | __main__:parse_data:21 - processing page: 160 SKODA 13
# 2021-03-06 12:38:43.615 | INFO     | __main__:parse_data:21 - processing page: 161 TOYOTA 19
# 2021-03-06 12:38:44.157 | INFO     | __main__:parse_data:21 - processing page: 162 INFINITI 4
# 2021-03-06 12:38:44.824 | INFO     | __main__:parse_data:21 - processing page: 163 BMW 22
# 2021-03-06 12:38:45.408 | INFO     | __main__:parse_data:21 - processing page: 164 VOLVO 7
# 2021-03-06 12:38:45.877 | INFO     | __main__:parse_data:21 - processing page: 165 MITSUBISHI 14
# 2021-03-06 12:38:46.450 | INFO     | __main__:parse_data:21 - processing page: 166 VOLKSWAGEN 22
# 2021-03-06 12:38:47.063 | INFO     | __main__:parse_data:21 - processing page: 167 AUDI 17
# 2021-03-06 12:38:47.666 | INFO     | __main__:parse_data:21 - processing page: 168 NISSAN 22
# 2021-03-06 12:38:48.124 | INFO     | __main__:parse_data:21 - processing page: 169 MERCEDES 21
# 2021-03-06 12:38:48.691 | INFO     | __main__:parse_data:21 - processing page: 170 TOYOTA 20
# 2021-03-06 12:38:49.449 | INFO     | __main__:parse_data:21 - processing page: 171 BMW 23
# 2021-03-06 12:38:50.096 | INFO     | __main__:parse_data:21 - processing page: 172 SKODA 14
# 2021-03-06 12:38:50.637 | INFO     | __main__:parse_data:21 - processing page: 173 LEXUS 4
# 2021-03-06 12:38:51.400 | INFO     | __main__:parse_data:21 - processing page: 174 VOLKSWAGEN 23
# 2021-03-06 12:38:51.977 | INFO     | __main__:parse_data:21 - processing page: 175 NISSAN 23
# 2021-03-06 12:38:52.545 | INFO     | __main__:parse_data:21 - processing page: 176 MERCEDES 22
# 2021-03-06 12:38:53.150 | INFO     | __main__:parse_data:21 - processing page: 177 AUDI 18
# 2021-03-06 12:38:53.654 | INFO     | __main__:parse_data:21 - processing page: 178 MITSUBISHI 15
# 2021-03-06 12:38:54.141 | INFO     | __main__:parse_data:21 - processing page: 179 BMW 24
# 2021-03-06 12:38:54.678 | INFO     | __main__:parse_data:21 - processing page: 180 TOYOTA 21
# 2021-03-06 12:38:55.301 | INFO     | __main__:parse_data:21 - processing page: 181 VOLKSWAGEN 24
# 2021-03-06 12:38:55.828 | INFO     | __main__:parse_data:21 - processing page: 182 NISSAN 24
# 2021-03-06 12:38:56.399 | INFO     | __main__:parse_data:21 - processing page: 183 HONDA 6
# 2021-03-06 12:38:56.935 | INFO     | __main__:parse_data:21 - processing page: 184 MERCEDES 23
# 2021-03-06 12:38:57.468 | INFO     | __main__:parse_data:21 - processing page: 185 SKODA 15
# 2021-03-06 12:38:57.982 | INFO     | __main__:parse_data:21 - processing page: 186 AUDI 19
# 2021-03-06 12:38:58.486 | INFO     | __main__:parse_data:21 - processing page: 187 BMW 25
# 2021-03-06 12:38:59.083 | INFO     | __main__:parse_data:21 - processing page: 188 TOYOTA 22
# 2021-03-06 12:38:59.782 | INFO     | __main__:parse_data:21 - processing page: 189 VOLVO 8
# 2021-03-06 12:39:00.354 | INFO     | __main__:parse_data:21 - processing page: 190 VOLKSWAGEN 25
# 2021-03-06 12:39:01.013 | INFO     | __main__:parse_data:21 - processing page: 191 NISSAN 25
# 2021-03-06 12:39:01.575 | INFO     | __main__:parse_data:21 - processing page: 192 MITSUBISHI 16
# 2021-03-06 12:39:02.146 | INFO     | __main__:parse_data:21 - processing page: 193 MERCEDES 24
# 2021-03-06 12:39:02.721 | INFO     | __main__:parse_data:21 - processing page: 194 BMW 26
# 2021-03-06 12:39:03.293 | INFO     | __main__:parse_data:21 - processing page: 195 AUDI 20
# 2021-03-06 12:39:03.949 | INFO     | __main__:parse_data:21 - processing page: 196 SKODA 16
# 2021-03-06 12:39:04.552 | INFO     | __main__:parse_data:21 - processing page: 197 TOYOTA 23
# 2021-03-06 12:39:05.015 | INFO     | __main__:parse_data:21 - processing page: 198 VOLKSWAGEN 26
# 2021-03-06 12:39:05.541 | INFO     | __main__:parse_data:21 - processing page: 199 NISSAN 26
# 2021-03-06 12:39:05.997 | INFO     | __main__:parse_data:21 - processing page: 200 MERCEDES 25
# 2021-03-06 12:39:06.618 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_200.csv, содержащий 1850 записей
# 2021-03-06 12:39:06.918 | INFO     | __main__:parse_data:21 - processing page: 201 MITSUBISHI 17
# 2021-03-06 12:39:07.303 | INFO     | __main__:parse_data:21 - processing page: 202 BMW 27
# 2021-03-06 12:39:07.980 | INFO     | __main__:parse_data:21 - processing page: 203 INFINITI 5
# 2021-03-06 12:39:08.622 | INFO     | __main__:parse_data:21 - processing page: 204 VOLKSWAGEN 27
# 2021-03-06 12:39:09.172 | INFO     | __main__:parse_data:21 - processing page: 205 TOYOTA 24
# 2021-03-06 12:39:09.847 | INFO     | __main__:parse_data:21 - processing page: 206 NISSAN 27
# 2021-03-06 12:39:10.361 | INFO     | __main__:parse_data:21 - processing page: 207 AUDI 21
# 2021-03-06 12:39:10.925 | INFO     | __main__:parse_data:21 - processing page: 208 MERCEDES 26
# 2021-03-06 12:39:11.472 | INFO     | __main__:parse_data:21 - processing page: 209 SKODA 17
# 2021-03-06 12:39:11.996 | INFO     | __main__:parse_data:21 - processing page: 210 BMW 28
# 2021-03-06 12:39:12.558 | INFO     | __main__:parse_data:21 - processing page: 211 VOLVO 9
# 2021-03-06 12:39:13.115 | INFO     | __main__:parse_data:21 - processing page: 212 HONDA 7
# 2021-03-06 12:39:13.636 | INFO     | __main__:parse_data:21 - processing page: 213 VOLKSWAGEN 28
# 2021-03-06 12:39:14.177 | INFO     | __main__:parse_data:21 - processing page: 214 NISSAN 28
# 2021-03-06 12:39:14.681 | INFO     | __main__:parse_data:21 - processing page: 215 MITSUBISHI 18
# 2021-03-06 12:39:15.125 | INFO     | __main__:parse_data:21 - processing page: 216 TOYOTA 25
# 2021-03-06 12:39:16.042 | INFO     | __main__:parse_data:21 - processing page: 217 AUDI 22
# 2021-03-06 12:39:16.585 | INFO     | __main__:parse_data:21 - processing page: 218 MERCEDES 27
# 2021-03-06 12:39:17.176 | INFO     | __main__:parse_data:21 - processing page: 219 BMW 29
# 2021-03-06 12:39:17.880 | INFO     | __main__:parse_data:21 - processing page: 220 LEXUS 5
# 2021-03-06 12:39:18.675 | INFO     | __main__:parse_data:21 - processing page: 221 VOLKSWAGEN 29
# 2021-03-06 12:39:19.283 | INFO     | __main__:parse_data:21 - processing page: 222 NISSAN 29
# 2021-03-06 12:39:19.762 | INFO     | __main__:parse_data:21 - processing page: 223 SKODA 18
# 2021-03-06 12:39:20.318 | INFO     | __main__:parse_data:21 - processing page: 224 TOYOTA 26
# 2021-03-06 12:39:20.924 | INFO     | __main__:parse_data:21 - processing page: 225 MERCEDES 28
# 2021-03-06 12:39:21.418 | INFO     | __main__:parse_data:21 - processing page: 226 BMW 30
# 2021-03-06 12:39:22.100 | INFO     | __main__:parse_data:21 - processing page: 227 MITSUBISHI 19
# 2021-03-06 12:39:22.548 | INFO     | __main__:parse_data:21 - processing page: 228 AUDI 23
# 2021-03-06 12:39:23.089 | INFO     | __main__:parse_data:21 - processing page: 229 VOLKSWAGEN 30
# 2021-03-06 12:39:23.548 | INFO     | __main__:parse_data:21 - processing page: 230 NISSAN 30
# 2021-03-06 12:39:24.073 | INFO     | __main__:parse_data:21 - processing page: 231 TOYOTA 27
# 2021-03-06 12:39:24.480 | INFO     | __main__:parse_data:21 - processing page: 232 BMW 31
# 2021-03-06 12:39:25.003 | INFO     | __main__:parse_data:21 - processing page: 233 MERCEDES 29
# 2021-03-06 12:39:25.573 | INFO     | __main__:parse_data:21 - processing page: 234 SKODA 19
# 2021-03-06 12:39:26.177 | INFO     | __main__:parse_data:21 - processing page: 235 VOLVO 10
# 2021-03-06 12:39:26.570 | INFO     | __main__:parse_data:21 - processing page: 236 AUDI 24
# 2021-03-06 12:39:27.086 | INFO     | __main__:parse_data:21 - processing page: 237 VOLKSWAGEN 31
# 2021-03-06 12:39:27.561 | INFO     | __main__:parse_data:21 - processing page: 238 NISSAN 31
# 2021-03-06 12:39:27.959 | INFO     | __main__:parse_data:21 - processing page: 239 MITSUBISHI 20
# 2021-03-06 12:39:28.363 | INFO     | __main__:parse_data:21 - processing page: 240 BMW 32
# 2021-03-06 12:39:29.060 | INFO     | __main__:parse_data:21 - processing page: 241 TOYOTA 28
# 2021-03-06 12:39:29.455 | INFO     | __main__:parse_data:21 - processing page: 242 MERCEDES 30
# 2021-03-06 12:39:30.264 | INFO     | __main__:parse_data:21 - processing page: 243 HONDA 8
# 2021-03-06 12:39:30.733 | INFO     | __main__:parse_data:21 - processing page: 244 INFINITI 6
# 2021-03-06 12:39:31.157 | INFO     | __main__:parse_data:21 - processing page: 245 VOLKSWAGEN 32
# 2021-03-06 12:39:31.691 | INFO     | __main__:parse_data:21 - processing page: 246 NISSAN 32
# 2021-03-06 12:39:32.229 | INFO     | __main__:parse_data:21 - processing page: 247 AUDI 25
# 2021-03-06 12:39:32.781 | INFO     | __main__:parse_data:21 - processing page: 248 SKODA 20
# 2021-03-06 12:39:33.334 | INFO     | __main__:parse_data:21 - processing page: 249 BMW 33
# 2021-03-06 12:39:33.831 | INFO     | __main__:parse_data:21 - processing page: 250 MERCEDES 31
# 2021-03-06 12:39:34.326 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_250.csv, содержащий 1850 записей
# 2021-03-06 12:39:34.610 | INFO     | __main__:parse_data:21 - processing page: 251 TOYOTA 29
# 2021-03-06 12:39:35.013 | INFO     | __main__:parse_data:21 - processing page: 252 MITSUBISHI 21
# 2021-03-06 12:39:35.498 | INFO     | __main__:parse_data:21 - processing page: 253 VOLKSWAGEN 33
# 2021-03-06 12:39:35.931 | INFO     | __main__:parse_data:21 - processing page: 254 NISSAN 33
# 2021-03-06 12:39:36.371 | INFO     | __main__:parse_data:21 - processing page: 255 LEXUS 6
# 2021-03-06 12:39:36.946 | INFO     | __main__:parse_data:21 - processing page: 256 BMW 34
# 2021-03-06 12:39:37.446 | INFO     | __main__:parse_data:21 - processing page: 257 AUDI 26
# 2021-03-06 12:39:37.829 | INFO     | __main__:parse_data:21 - processing page: 258 MERCEDES 32
# 2021-03-06 12:39:38.623 | INFO     | __main__:parse_data:21 - processing page: 259 TOYOTA 30
# 2021-03-06 12:39:39.122 | INFO     | __main__:parse_data:21 - processing page: 260 VOLVO 11
# 2021-03-06 12:39:39.743 | INFO     | __main__:parse_data:21 - processing page: 261 VOLKSWAGEN 34
# 2021-03-06 12:39:40.157 | INFO     | __main__:parse_data:21 - processing page: 262 NISSAN 34
# 2021-03-06 12:39:40.713 | INFO     | __main__:parse_data:21 - processing page: 263 SKODA 21
# 2021-03-06 12:39:41.298 | INFO     | __main__:parse_data:21 - processing page: 264 MITSUBISHI 22
# 2021-03-06 12:39:41.641 | INFO     | __main__:parse_data:21 - processing page: 265 BMW 35
# 2021-03-06 12:39:42.135 | INFO     | __main__:parse_data:21 - processing page: 266 MERCEDES 33
# 2021-03-06 12:39:42.709 | INFO     | __main__:parse_data:21 - processing page: 267 AUDI 27
# 2021-03-06 12:39:43.127 | INFO     | __main__:parse_data:21 - processing page: 268 TOYOTA 31
# 2021-03-06 12:39:43.644 | INFO     | __main__:parse_data:21 - processing page: 269 VOLKSWAGEN 35
# 2021-03-06 12:39:44.070 | INFO     | __main__:parse_data:21 - processing page: 270 NISSAN 35
# 2021-03-06 12:39:44.513 | INFO     | __main__:parse_data:21 - processing page: 271 BMW 36
# 2021-03-06 12:39:45.130 | INFO     | __main__:parse_data:21 - processing page: 272 HONDA 9
# 2021-03-06 12:39:45.562 | INFO     | __main__:parse_data:21 - processing page: 273 SKODA 22
# 2021-03-06 12:39:46.109 | INFO     | __main__:parse_data:21 - processing page: 274 MITSUBISHI 23
# 2021-03-06 12:39:46.544 | INFO     | __main__:parse_data:21 - processing page: 275 MERCEDES 34
# 2021-03-06 12:39:47.171 | INFO     | __main__:parse_data:21 - processing page: 276 VOLKSWAGEN 36
# 2021-03-06 12:39:47.540 | INFO     | __main__:parse_data:21 - processing page: 277 TOYOTA 32
# 2021-03-06 12:39:48.071 | INFO     | __main__:parse_data:21 - processing page: 278 NISSAN 36
# 2021-03-06 12:39:48.493 | INFO     | __main__:parse_data:21 - processing page: 279 AUDI 28
# 2021-03-06 12:39:48.927 | INFO     | __main__:parse_data:21 - processing page: 280 BMW 37
# 2021-03-06 12:39:49.641 | INFO     | __main__:parse_data:21 - processing page: 281 INFINITI 7
# 2021-03-06 12:39:50.071 | INFO     | __main__:parse_data:21 - processing page: 282 VOLVO 12
# 2021-03-06 12:39:50.592 | INFO     | __main__:parse_data:21 - processing page: 283 MERCEDES 35
# 2021-03-06 12:39:51.131 | INFO     | __main__:parse_data:21 - processing page: 284 VOLKSWAGEN 37
# 2021-03-06 12:39:51.503 | INFO     | __main__:parse_data:21 - processing page: 285 NISSAN 37
# 2021-03-06 12:39:51.911 | INFO     | __main__:parse_data:21 - processing page: 286 TOYOTA 33
# 2021-03-06 12:39:52.400 | INFO     | __main__:parse_data:21 - processing page: 287 SKODA 23
# 2021-03-06 12:39:52.829 | INFO     | __main__:parse_data:21 - processing page: 288 BMW 38
# 2021-03-06 12:39:53.328 | INFO     | __main__:parse_data:21 - processing page: 289 MITSUBISHI 24
# 2021-03-06 12:39:53.674 | INFO     | __main__:parse_data:21 - processing page: 290 AUDI 29
# 2021-03-06 12:39:54.088 | INFO     | __main__:parse_data:21 - processing page: 291 MERCEDES 36
# 2021-03-06 12:39:54.733 | INFO     | __main__:parse_data:21 - processing page: 292 VOLKSWAGEN 38
# 2021-03-06 12:39:55.102 | INFO     | __main__:parse_data:21 - processing page: 293 NISSAN 38
# 2021-03-06 12:39:55.583 | INFO     | __main__:parse_data:21 - processing page: 294 TOYOTA 34
# 2021-03-06 12:39:55.989 | INFO     | __main__:parse_data:21 - processing page: 295 BMW 39
# 2021-03-06 12:39:56.494 | INFO     | __main__:parse_data:21 - processing page: 296 LEXUS 7
# 2021-03-06 12:39:57.039 | INFO     | __main__:parse_data:21 - processing page: 297 AUDI 30
# 2021-03-06 12:39:57.549 | INFO     | __main__:parse_data:21 - processing page: 298 SKODA 24
# 2021-03-06 12:39:58.021 | INFO     | __main__:parse_data:21 - processing page: 299 MITSUBISHI 25
# 2021-03-06 12:39:58.390 | INFO     | __main__:parse_data:21 - processing page: 300 VOLKSWAGEN 39
# 2021-03-06 12:39:58.849 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_300.csv, содержащий 1850 записей
# 2021-03-06 12:39:59.118 | INFO     | __main__:parse_data:21 - processing page: 301 MERCEDES 37
# 2021-03-06 12:39:59.635 | INFO     | __main__:parse_data:21 - processing page: 302 NISSAN 39
# 2021-03-06 12:40:00.134 | INFO     | __main__:parse_data:21 - processing page: 303 BMW 40
# 2021-03-06 12:40:00.730 | INFO     | __main__:parse_data:21 - processing page: 304 TOYOTA 35
# 2021-03-06 12:40:01.167 | INFO     | __main__:parse_data:21 - processing page: 305 HONDA 10
# 2021-03-06 12:40:01.662 | INFO     | __main__:parse_data:21 - processing page: 306 VOLVO 13
# 2021-03-06 12:40:02.102 | INFO     | __main__:parse_data:21 - processing page: 307 VOLKSWAGEN 40
# 2021-03-06 12:40:02.488 | INFO     | __main__:parse_data:21 - processing page: 308 AUDI 31
# 2021-03-06 12:40:02.979 | INFO     | __main__:parse_data:21 - processing page: 309 MERCEDES 38
# 2021-03-06 12:40:03.687 | INFO     | __main__:parse_data:21 - processing page: 310 NISSAN 40
# 2021-03-06 12:40:04.088 | INFO     | __main__:parse_data:21 - processing page: 311 BMW 41
# 2021-03-06 12:40:04.631 | INFO     | __main__:parse_data:21 - processing page: 312 SKODA 25
# 2021-03-06 12:40:05.027 | INFO     | __main__:parse_data:21 - processing page: 313 MITSUBISHI 26
# 2021-03-06 12:40:05.469 | INFO     | __main__:parse_data:21 - processing page: 314 TOYOTA 36
# 2021-03-06 12:40:06.018 | INFO     | __main__:parse_data:21 - processing page: 315 VOLKSWAGEN 41
# 2021-03-06 12:40:06.443 | INFO     | __main__:parse_data:21 - processing page: 316 NISSAN 41
# 2021-03-06 12:40:06.830 | INFO     | __main__:parse_data:21 - processing page: 317 MERCEDES 39
# 2021-03-06 12:40:07.331 | INFO     | __main__:parse_data:21 - processing page: 318 AUDI 32
# 2021-03-06 12:40:07.911 | INFO     | __main__:parse_data:21 - processing page: 319 BMW 42
# 2021-03-06 12:40:08.381 | INFO     | __main__:parse_data:21 - processing page: 320 TOYOTA 37
# 2021-03-06 12:40:08.910 | INFO     | __main__:parse_data:21 - processing page: 321 INFINITI 8
# 2021-03-06 12:40:09.387 | INFO     | __main__:parse_data:21 - processing page: 322 SKODA 26
# 2021-03-06 12:40:09.857 | INFO     | __main__:parse_data:21 - processing page: 323 VOLKSWAGEN 42
# 2021-03-06 12:40:10.320 | INFO     | __main__:parse_data:21 - processing page: 324 MITSUBISHI 27
# 2021-03-06 12:40:10.688 | INFO     | __main__:parse_data:21 - processing page: 325 NISSAN 42
# 2021-03-06 12:40:11.198 | INFO     | __main__:parse_data:21 - processing page: 326 MERCEDES 40
# 2021-03-06 12:40:11.772 | INFO     | __main__:parse_data:21 - processing page: 327 BMW 43
# 2021-03-06 12:40:12.205 | INFO     | __main__:parse_data:21 - processing page: 328 AUDI 33
# 2021-03-06 12:40:12.699 | INFO     | __main__:parse_data:21 - processing page: 329 TOYOTA 38
# 2021-03-06 12:40:13.346 | INFO     | __main__:parse_data:21 - processing page: 330 VOLVO 14
# 2021-03-06 12:40:13.722 | INFO     | __main__:parse_data:21 - processing page: 331 VOLKSWAGEN 43
# 2021-03-06 12:40:14.408 | INFO     | __main__:parse_data:21 - processing page: 332 NISSAN 43
# 2021-03-06 12:40:14.839 | INFO     | __main__:parse_data:21 - processing page: 333 MERCEDES 41
# 2021-03-06 12:40:15.592 | INFO     | __main__:parse_data:21 - processing page: 334 BMW 44
# 2021-03-06 12:40:16.163 | INFO     | __main__:parse_data:21 - processing page: 335 HONDA 11
# 2021-03-06 12:40:16.556 | INFO     | __main__:parse_data:21 - processing page: 336 MITSUBISHI 28
# 2021-03-06 12:40:17.041 | INFO     | __main__:parse_data:21 - processing page: 337 SKODA 27
# 2021-03-06 12:40:17.419 | INFO     | __main__:parse_data:21 - processing page: 338 AUDI 34
# 2021-03-06 12:40:17.900 | INFO     | __main__:parse_data:21 - processing page: 339 TOYOTA 39
# 2021-03-06 12:40:18.277 | INFO     | __main__:parse_data:21 - processing page: 340 VOLKSWAGEN 44
# 2021-03-06 12:40:18.879 | INFO     | __main__:parse_data:21 - processing page: 341 NISSAN 44
# 2021-03-06 12:40:19.425 | INFO     | __main__:parse_data:21 - processing page: 342 MERCEDES 42
# 2021-03-06 12:40:19.927 | INFO     | __main__:parse_data:21 - processing page: 343 BMW 45
# 2021-03-06 12:40:20.382 | INFO     | __main__:parse_data:21 - processing page: 344 LEXUS 8
# 2021-03-06 12:40:20.972 | INFO     | __main__:parse_data:21 - processing page: 345 VOLKSWAGEN 45
# 2021-03-06 12:40:21.462 | INFO     | __main__:parse_data:21 - processing page: 346 TOYOTA 40
# 2021-03-06 12:40:21.973 | INFO     | __main__:parse_data:21 - processing page: 347 MITSUBISHI 29
# 2021-03-06 12:40:22.341 | INFO     | __main__:parse_data:21 - processing page: 348 NISSAN 45
# 2021-03-06 12:40:22.804 | INFO     | __main__:parse_data:21 - processing page: 349 AUDI 35
# 2021-03-06 12:40:23.275 | INFO     | __main__:parse_data:21 - processing page: 350 BMW 46
# 2021-03-06 12:40:23.732 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_350.csv, содержащий 1850 записей
# 2021-03-06 12:40:23.996 | INFO     | __main__:parse_data:21 - processing page: 351 MERCEDES 43
# 2021-03-06 12:40:24.524 | INFO     | __main__:parse_data:21 - processing page: 352 SKODA 28
# 2021-03-06 12:40:24.917 | INFO     | __main__:parse_data:21 - processing page: 353 VOLVO 15
# 2021-03-06 12:40:25.450 | INFO     | __main__:parse_data:21 - processing page: 354 VOLKSWAGEN 46
# 2021-03-06 12:40:25.896 | INFO     | __main__:parse_data:21 - processing page: 355 NISSAN 46
# 2021-03-06 12:40:26.265 | INFO     | __main__:parse_data:21 - processing page: 356 TOYOTA 41
# 2021-03-06 12:40:26.743 | INFO     | __main__:parse_data:21 - processing page: 357 BMW 47
# 2021-03-06 12:40:27.224 | INFO     | __main__:parse_data:21 - processing page: 358 MERCEDES 44
# 2021-03-06 12:40:27.942 | INFO     | __main__:parse_data:21 - processing page: 359 AUDI 36
# 2021-03-06 12:40:28.421 | INFO     | __main__:parse_data:21 - processing page: 360 MITSUBISHI 30
# 2021-03-06 12:40:28.855 | INFO     | __main__:parse_data:21 - processing page: 361 SKODA 29
# 2021-03-06 12:40:29.397 | INFO     | __main__:parse_data:21 - processing page: 362 HONDA 12
# 2021-03-06 12:40:29.711 | INFO     | __main__:parse_data:21 - processing page: 363 VOLKSWAGEN 47
# 2021-03-06 12:40:30.273 | INFO     | __main__:parse_data:21 - processing page: 364 NISSAN 47
# 2021-03-06 12:40:30.669 | INFO     | __main__:parse_data:21 - processing page: 365 BMW 48
# 2021-03-06 12:40:31.216 | INFO     | __main__:parse_data:21 - processing page: 366 TOYOTA 42
# 2021-03-06 12:40:31.699 | INFO     | __main__:parse_data:21 - processing page: 367 MERCEDES 45
# 2021-03-06 12:40:32.206 | INFO     | __main__:parse_data:21 - processing page: 368 INFINITI 9
# 2021-03-06 12:40:32.613 | INFO     | __main__:parse_data:21 - processing page: 369 AUDI 37
# 2021-03-06 12:40:33.064 | INFO     | __main__:parse_data:21 - processing page: 370 VOLKSWAGEN 48
# 2021-03-06 12:40:33.425 | INFO     | __main__:parse_data:21 - processing page: 371 NISSAN 48
# 2021-03-06 12:40:33.913 | INFO     | __main__:parse_data:21 - processing page: 372 MITSUBISHI 31
# 2021-03-06 12:40:34.343 | INFO     | __main__:parse_data:21 - processing page: 373 BMW 49
# 2021-03-06 12:40:34.852 | INFO     | __main__:parse_data:21 - processing page: 374 TOYOTA 43
# 2021-03-06 12:40:35.222 | INFO     | __main__:parse_data:21 - processing page: 375 MERCEDES 46
# 2021-03-06 12:40:35.880 | INFO     | __main__:parse_data:21 - processing page: 376 SKODA 30
# 2021-03-06 12:40:36.282 | INFO     | __main__:parse_data:21 - processing page: 377 VOLVO 16
# 2021-03-06 12:40:36.730 | INFO     | __main__:parse_data:21 - processing page: 378 VOLKSWAGEN 49
# 2021-03-06 12:40:37.142 | INFO     | __main__:parse_data:21 - processing page: 379 AUDI 38
# 2021-03-06 12:40:37.571 | INFO     | __main__:parse_data:21 - processing page: 380 NISSAN 49
# 2021-03-06 12:40:37.996 | INFO     | __main__:parse_data:21 - processing page: 381 BMW 50
# 2021-03-06 12:40:38.427 | INFO     | __main__:parse_data:21 - processing page: 382 LEXUS 9
# 2021-03-06 12:40:38.854 | INFO     | __main__:parse_data:21 - processing page: 383 MERCEDES 47
# 2021-03-06 12:40:39.397 | INFO     | __main__:parse_data:21 - processing page: 384 TOYOTA 44
# 2021-03-06 12:40:39.793 | INFO     | __main__:parse_data:21 - processing page: 385 MITSUBISHI 32
# 2021-03-06 12:40:40.175 | INFO     | __main__:parse_data:21 - processing page: 386 VOLKSWAGEN 50
# 2021-03-06 12:40:40.654 | INFO     | __main__:parse_data:21 - processing page: 387 SKODA 31
# 2021-03-06 12:40:41.160 | INFO     | __main__:parse_data:21 - processing page: 388 NISSAN 50
# 2021-03-06 12:40:41.594 | INFO     | __main__:parse_data:21 - processing page: 389 BMW 51
# 2021-03-06 12:40:42.105 | INFO     | __main__:parse_data:21 - processing page: 390 AUDI 39
# 2021-03-06 12:40:42.610 | INFO     | __main__:parse_data:21 - processing page: 391 MERCEDES 48
# 2021-03-06 12:40:43.136 | INFO     | __main__:parse_data:21 - processing page: 392 TOYOTA 45
# 2021-03-06 12:40:43.621 | INFO     | __main__:parse_data:21 - processing page: 393 HONDA 13
# 2021-03-06 12:40:43.949 | INFO     | __main__:parse_data:21 - processing page: 394 VOLKSWAGEN 51
# 2021-03-06 12:40:44.313 | INFO     | __main__:parse_data:21 - processing page: 395 NISSAN 51
# 2021-03-06 12:40:44.724 | INFO     | __main__:parse_data:21 - processing page: 396 BMW 52
# 2021-03-06 12:40:45.302 | INFO     | __main__:parse_data:21 - processing page: 397 MITSUBISHI 33
# 2021-03-06 12:40:45.669 | INFO     | __main__:parse_data:21 - processing page: 398 AUDI 40
# 2021-03-06 12:40:46.275 | INFO     | __main__:parse_data:21 - processing page: 399 MERCEDES 49
# 2021-03-06 12:40:46.800 | INFO     | __main__:parse_data:21 - processing page: 400 SKODA 32
# 2021-03-06 12:40:47.202 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_400.csv, содержащий 1849 записей
# 2021-03-06 12:40:47.484 | INFO     | __main__:parse_data:21 - processing page: 401 TOYOTA 46
# 2021-03-06 12:40:47.972 | INFO     | __main__:parse_data:21 - processing page: 402 VOLKSWAGEN 52
# 2021-03-06 12:40:48.392 | INFO     | __main__:parse_data:21 - processing page: 403 VOLVO 17
# 2021-03-06 12:40:48.772 | INFO     | __main__:parse_data:21 - processing page: 404 NISSAN 52
# 2021-03-06 12:40:49.216 | INFO     | __main__:parse_data:21 - processing page: 405 BMW 53
# 2021-03-06 12:40:49.722 | INFO     | __main__:parse_data:21 - processing page: 406 INFINITI 10
# 2021-03-06 12:40:50.197 | INFO     | __main__:parse_data:21 - processing page: 407 MERCEDES 50
# 2021-03-06 12:40:50.775 | INFO     | __main__:parse_data:21 - processing page: 408 MITSUBISHI 34
# 2021-03-06 12:40:51.211 | INFO     | __main__:parse_data:21 - processing page: 409 AUDI 41
# 2021-03-06 12:40:51.619 | INFO     | __main__:parse_data:21 - processing page: 410 TOYOTA 47
# 2021-03-06 12:40:52.001 | INFO     | __main__:parse_data:21 - processing page: 411 VOLKSWAGEN 53
# 2021-03-06 12:40:52.341 | INFO     | __main__:parse_data:21 - processing page: 412 NISSAN 53
# 2021-03-06 12:40:52.943 | INFO     | __main__:parse_data:21 - processing page: 413 BMW 54
# 2021-03-06 12:40:53.344 | INFO     | __main__:parse_data:21 - processing page: 414 SKODA 33
# 2021-03-06 12:40:53.762 | INFO     | __main__:parse_data:21 - processing page: 415 MERCEDES 51
# 2021-03-06 12:40:54.299 | INFO     | __main__:parse_data:21 - processing page: 416 LEXUS 10
# 2021-03-06 12:40:54.962 | INFO     | __main__:parse_data:21 - processing page: 417 VOLKSWAGEN 54
# 2021-03-06 12:40:55.513 | INFO     | __main__:parse_data:21 - processing page: 418 TOYOTA 48
# 2021-03-06 12:40:55.977 | INFO     | __main__:parse_data:21 - processing page: 419 NISSAN 54
# 2021-03-06 12:40:56.516 | INFO     | __main__:parse_data:21 - processing page: 420 BMW 55
# 2021-03-06 12:40:57.130 | INFO     | __main__:parse_data:21 - processing page: 421 AUDI 42
# 2021-03-06 12:40:57.717 | INFO     | __main__:parse_data:21 - processing page: 422 MITSUBISHI 35
# 2021-03-06 12:40:58.189 | INFO     | __main__:parse_data:21 - processing page: 423 HONDA 14
# 2021-03-06 12:40:58.615 | INFO     | __main__:parse_data:21 - processing page: 424 MERCEDES 52
# 2021-03-06 12:40:59.127 | INFO     | __main__:parse_data:21 - processing page: 425 SKODA 34
# 2021-03-06 12:40:59.526 | INFO     | __main__:parse_data:21 - processing page: 426 VOLKSWAGEN 55
# 2021-03-06 12:40:59.884 | INFO     | __main__:parse_data:21 - processing page: 427 BMW 56
# 2021-03-06 12:41:00.341 | INFO     | __main__:parse_data:21 - processing page: 428 NISSAN 55
# 2021-03-06 12:41:00.860 | INFO     | __main__:parse_data:21 - processing page: 429 TOYOTA 49
# 2021-03-06 12:41:01.382 | INFO     | __main__:parse_data:21 - processing page: 430 VOLVO 18
# 2021-03-06 12:41:01.804 | INFO     | __main__:parse_data:21 - processing page: 431 AUDI 43
# 2021-03-06 12:41:02.395 | INFO     | __main__:parse_data:21 - processing page: 432 MERCEDES 53
# 2021-03-06 12:41:02.858 | INFO     | __main__:parse_data:21 - processing page: 433 MITSUBISHI 36
# 2021-03-06 12:41:03.334 | INFO     | __main__:parse_data:21 - processing page: 434 VOLKSWAGEN 56
# 2021-03-06 12:41:03.896 | INFO     | __main__:parse_data:21 - processing page: 435 BMW 57
# 2021-03-06 12:41:04.397 | INFO     | __main__:parse_data:21 - processing page: 436 NISSAN 56
# 2021-03-06 12:41:04.848 | INFO     | __main__:parse_data:21 - processing page: 437 TOYOTA 50
# 2021-03-06 12:41:05.229 | INFO     | __main__:parse_data:21 - processing page: 438 SKODA 35
# 2021-03-06 12:41:05.683 | INFO     | __main__:parse_data:21 - processing page: 439 AUDI 44
# 2021-03-06 12:41:06.072 | INFO     | __main__:parse_data:21 - processing page: 440 MERCEDES 54
# 2021-03-06 12:41:06.505 | INFO     | __main__:parse_data:21 - processing page: 441 VOLKSWAGEN 57
# 2021-03-06 12:41:06.948 | INFO     | __main__:parse_data:21 - processing page: 442 BMW 58
# 2021-03-06 12:41:07.438 | INFO     | __main__:parse_data:21 - processing page: 443 NISSAN 57
# 2021-03-06 12:41:07.832 | INFO     | __main__:parse_data:21 - processing page: 444 INFINITI 11
# 2021-03-06 12:41:08.304 | INFO     | __main__:parse_data:21 - processing page: 445 TOYOTA 51
# 2021-03-06 12:41:08.781 | INFO     | __main__:parse_data:21 - processing page: 446 MITSUBISHI 37
# 2021-03-06 12:41:09.389 | INFO     | __main__:parse_data:21 - processing page: 447 VOLVO 19
# 2021-03-06 12:41:09.842 | INFO     | __main__:parse_data:21 - processing page: 448 MERCEDES 55
# 2021-03-06 12:41:10.417 | INFO     | __main__:parse_data:21 - processing page: 449 VOLKSWAGEN 58
# 2021-03-06 12:41:10.907 | INFO     | __main__:parse_data:21 - processing page: 450 AUDI 45
# 2021-03-06 12:41:11.448 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_450.csv, содержащий 1849 записей
# 2021-03-06 12:41:11.712 | INFO     | __main__:parse_data:21 - processing page: 451 BMW 59
# 2021-03-06 12:41:12.215 | INFO     | __main__:parse_data:21 - processing page: 452 NISSAN 58
# 2021-03-06 12:41:12.744 | INFO     | __main__:parse_data:21 - processing page: 453 SKODA 36
# 2021-03-06 12:41:13.268 | INFO     | __main__:parse_data:21 - processing page: 454 TOYOTA 52
# 2021-03-06 12:41:13.736 | INFO     | __main__:parse_data:21 - processing page: 455 HONDA 15
# 2021-03-06 12:41:14.231 | INFO     | __main__:parse_data:21 - processing page: 456 VOLKSWAGEN 59
# 2021-03-06 12:41:14.675 | INFO     | __main__:parse_data:21 - processing page: 457 MERCEDES 56
# 2021-03-06 12:41:15.174 | INFO     | __main__:parse_data:21 - processing page: 458 BMW 60
# 2021-03-06 12:41:15.728 | INFO     | __main__:parse_data:21 - processing page: 459 NISSAN 59
# 2021-03-06 12:41:16.110 | INFO     | __main__:parse_data:21 - processing page: 460 MITSUBISHI 38
# 2021-03-06 12:41:16.558 | INFO     | __main__:parse_data:21 - processing page: 461 AUDI 46
# 2021-03-06 12:41:17.096 | INFO     | __main__:parse_data:21 - processing page: 462 SKODA 37
# 2021-03-06 12:41:17.505 | INFO     | __main__:parse_data:21 - processing page: 463 TOYOTA 53
# 2021-03-06 12:41:17.918 | INFO     | __main__:parse_data:21 - processing page: 464 LEXUS 11
# 2021-03-06 12:41:18.312 | INFO     | __main__:parse_data:21 - processing page: 465 VOLKSWAGEN 60
# 2021-03-06 12:41:18.796 | INFO     | __main__:parse_data:21 - processing page: 466 BMW 61
# 2021-03-06 12:41:19.230 | INFO     | __main__:parse_data:21 - processing page: 467 MERCEDES 57
# 2021-03-06 12:41:19.702 | INFO     | __main__:parse_data:21 - processing page: 468 NISSAN 60
# 2021-03-06 12:41:20.178 | INFO     | __main__:parse_data:21 - processing page: 469 MITSUBISHI 39
# 2021-03-06 12:41:20.641 | INFO     | __main__:parse_data:21 - processing page: 470 AUDI 47
# 2021-03-06 12:41:21.164 | INFO     | __main__:parse_data:21 - processing page: 471 TOYOTA 54
# 2021-03-06 12:41:21.671 | INFO     | __main__:parse_data:21 - processing page: 472 VOLVO 20
# 2021-03-06 12:41:22.088 | INFO     | __main__:parse_data:21 - processing page: 473 VOLKSWAGEN 61
# 2021-03-06 12:41:22.614 | INFO     | __main__:parse_data:21 - processing page: 474 BMW 62
# 2021-03-06 12:41:23.046 | INFO     | __main__:parse_data:21 - processing page: 475 MERCEDES 58
# 2021-03-06 12:41:23.650 | INFO     | __main__:parse_data:21 - processing page: 476 NISSAN 61
# 2021-03-06 12:41:24.076 | INFO     | __main__:parse_data:21 - processing page: 477 SKODA 38
# 2021-03-06 12:41:24.560 | INFO     | __main__:parse_data:21 - processing page: 478 INFINITI 12
# 2021-03-06 12:41:24.994 | INFO     | __main__:parse_data:21 - processing page: 479 AUDI 48
# 2021-03-06 12:41:25.656 | INFO     | __main__:parse_data:21 - processing page: 480 TOYOTA 55
# 2021-03-06 12:41:26.201 | INFO     | __main__:parse_data:21 - processing page: 481 VOLKSWAGEN 62
# 2021-03-06 12:41:26.592 | INFO     | __main__:parse_data:21 - processing page: 482 BMW 63
# 2021-03-06 12:41:27.048 | INFO     | __main__:parse_data:21 - processing page: 483 NISSAN 62
# 2021-03-06 12:41:27.406 | INFO     | __main__:parse_data:21 - processing page: 484 MERCEDES 59
# 2021-03-06 12:41:27.891 | INFO     | __main__:parse_data:21 - processing page: 485 MITSUBISHI 40
# 2021-03-06 12:41:28.317 | INFO     | __main__:parse_data:21 - processing page: 486 HONDA 16
# 2021-03-06 12:41:28.816 | INFO     | __main__:parse_data:21 - processing page: 487 SKODA 39
# 2021-03-06 12:41:29.277 | INFO     | __main__:parse_data:21 - processing page: 488 VOLKSWAGEN 63
# 2021-03-06 12:41:29.644 | INFO     | __main__:parse_data:21 - processing page: 489 BMW 64
# 2021-03-06 12:41:30.133 | INFO     | __main__:parse_data:21 - processing page: 490 TOYOTA 56
# 2021-03-06 12:41:30.543 | INFO     | __main__:parse_data:21 - processing page: 491 NISSAN 63
# 2021-03-06 12:41:30.942 | INFO     | __main__:parse_data:21 - processing page: 492 MERCEDES 60
# 2021-03-06 12:41:31.467 | INFO     | __main__:parse_data:21 - processing page: 493 AUDI 49
# 2021-03-06 12:41:31.980 | INFO     | __main__:parse_data:21 - processing page: 494 MITSUBISHI 41
# 2021-03-06 12:41:32.566 | INFO     | __main__:parse_data:21 - processing page: 495 VOLVO 21
# 2021-03-06 12:41:32.980 | INFO     | __main__:parse_data:21 - processing page: 496 BMW 65
# 2021-03-06 12:41:33.530 | INFO     | __main__:parse_data:21 - processing page: 497 VOLKSWAGEN 64
# 2021-03-06 12:41:33.946 | INFO     | __main__:parse_data:21 - processing page: 498 NISSAN 64
# 2021-03-06 12:41:34.448 | INFO     | __main__:parse_data:21 - processing page: 499 TOYOTA 57
# 2021-03-06 12:41:34.839 | INFO     | __main__:parse_data:21 - processing page: 500 MERCEDES 61
# 2021-03-06 12:41:35.367 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_500.csv, содержащий 1850 записей
# 2021-03-06 12:41:35.656 | INFO     | __main__:parse_data:21 - processing page: 501 AUDI 50
# 2021-03-06 12:41:36.013 | INFO     | __main__:parse_data:21 - processing page: 502 SKODA 40
# ...
# 2021-03-06 12:50:00.851 | INFO     | __main__:parse_data:21 - processing page: 1396 BMW 181
# 2021-03-06 12:50:01.471 | INFO     | __main__:parse_data:21 - processing page: 1397 MITSUBISHI 115
# 2021-03-06 12:50:02.157 | INFO     | __main__:parse_data:21 - processing page: 1398 NISSAN 178
# 2021-03-06 12:50:02.764 | INFO     | __main__:parse_data:21 - processing page: 1399 VOLVO 59
# 2021-03-06 12:50:03.051 | INFO     | __main__:parse_data:21 - processing page: 1400 SKODA 111
# 2021-03-06 12:50:03.830 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_1400.csv, содержащий 1801 записей
# 2021-03-06 12:50:04.120 | INFO     | __main__:parse_data:21 - processing page: 1401 INFINITI 35
# 2021-03-06 12:50:04.234 | INFO     | __main__:parse_data:21 - processing page: 1402 VOLKSWAGEN 179
# 2021-03-06 12:50:05.013 | INFO     | __main__:parse_data:21 - processing page: 1403 TOYOTA 159
# 2021-03-06 12:50:05.606 | INFO     | __main__:parse_data:21 - processing page: 1404 AUDI 139
# 2021-03-06 12:50:06.294 | INFO     | __main__:parse_data:21 - processing page: 1405 MERCEDES 170
# 2021-03-06 12:50:07.073 | INFO     | __main__:parse_data:21 - processing page: 1406 BMW 182
# 2021-03-06 12:50:07.812 | INFO     | __main__:parse_data:21 - processing page: 1407 NISSAN 179
# 2021-03-06 12:50:08.351 | INFO     | __main__:parse_data:21 - processing page: 1408 MITSUBISHI 116
# 2021-03-06 12:50:08.982 | INFO     | __main__:parse_data:21 - processing page: 1409 VOLKSWAGEN 180
# 2021-03-06 12:50:09.483 | INFO     | __main__:parse_data:21 - processing page: 1410 TOYOTA 160
# 2021-03-06 12:50:10.107 | INFO     | __main__:parse_data:21 - processing page: 1411 BMW 183
# 2021-03-06 12:50:10.711 | INFO     | __main__:parse_data:21 - processing page: 1412 MERCEDES 171
# 2021-03-06 12:50:11.314 | INFO     | __main__:parse_data:21 - processing page: 1413 SKODA 112
# 2021-03-06 12:50:11.975 | INFO     | __main__:parse_data:21 - processing page: 1414 AUDI 140
# 2021-03-06 12:50:12.655 | INFO     | __main__:parse_data:21 - processing page: 1415 NISSAN 180
# 2021-03-06 12:50:13.424 | INFO     | __main__:parse_data:21 - processing page: 1416 HONDA 47
# 2021-03-06 12:50:13.545 | INFO     | __main__:parse_data:21 - processing page: 1417 LEXUS 34
# 2021-03-06 12:50:14.043 | INFO     | __main__:parse_data:21 - processing page: 1418 VOLKSWAGEN 181
# 2021-03-06 12:50:14.564 | INFO     | __main__:parse_data:21 - processing page: 1419 BMW 184
# 2021-03-06 12:50:15.098 | INFO     | __main__:parse_data:21 - processing page: 1420 MERCEDES 172
# 2021-03-06 12:50:15.737 | INFO     | __main__:parse_data:21 - processing page: 1421 TOYOTA 161
# 2021-03-06 12:50:16.346 | INFO     | __main__:parse_data:21 - processing page: 1422 NISSAN 181
# 2021-03-06 12:50:16.891 | INFO     | __main__:parse_data:21 - processing page: 1423 MITSUBISHI 117
# 2021-03-06 12:50:17.525 | INFO     | __main__:parse_data:21 - processing page: 1424 AUDI 141
# 2021-03-06 12:50:18.110 | INFO     | __main__:parse_data:21 - processing page: 1425 VOLVO 60
# 2021-03-06 12:50:18.433 | INFO     | __main__:parse_data:21 - processing page: 1426 SKODA 113
# 2021-03-06 12:50:18.913 | INFO     | __main__:parse_data:21 - processing page: 1427 VOLKSWAGEN 182
# 2021-03-06 12:50:19.693 | INFO     | __main__:parse_data:21 - processing page: 1428 BMW 185
# 2021-03-06 12:50:20.323 | INFO     | __main__:parse_data:21 - processing page: 1429 MERCEDES 173
# 2021-03-06 12:50:20.930 | INFO     | __main__:parse_data:21 - processing page: 1430 TOYOTA 162
# 2021-03-06 12:50:21.544 | INFO     | __main__:parse_data:21 - processing page: 1431 NISSAN 182
# 2021-03-06 12:50:22.129 | INFO     | __main__:parse_data:21 - processing page: 1432 AUDI 142
# 2021-03-06 12:50:22.768 | INFO     | __main__:parse_data:21 - processing page: 1433 MITSUBISHI 118
# 2021-03-06 12:50:23.303 | INFO     | __main__:parse_data:21 - processing page: 1434 VOLKSWAGEN 183
# 2021-03-06 12:50:23.904 | INFO     | __main__:parse_data:21 - processing page: 1435 BMW 186
# 2021-03-06 12:50:24.436 | INFO     | __main__:parse_data:21 - processing page: 1436 MERCEDES 174
# 2021-03-06 12:50:24.973 | INFO     | __main__:parse_data:21 - processing page: 1437 SKODA 114
# 2021-03-06 12:50:25.562 | INFO     | __main__:parse_data:21 - processing page: 1438 NISSAN 183
# 2021-03-06 12:50:26.197 | INFO     | __main__:parse_data:21 - processing page: 1439 TOYOTA 163
# 2021-03-06 12:50:26.749 | INFO     | __main__:parse_data:21 - processing page: 1440 INFINITI 36
# 2021-03-06 12:50:26.921 | INFO     | __main__:parse_data:21 - processing page: 1441 VOLKSWAGEN 184
# 2021-03-06 12:50:27.576 | INFO     | __main__:parse_data:21 - processing page: 1442 BMW 187
# 2021-03-06 12:50:28.182 | INFO     | __main__:parse_data:21 - processing page: 1443 AUDI 143
# 2021-03-06 12:50:28.892 | INFO     | __main__:parse_data:21 - processing page: 1444 VOLVO 61
# 2021-03-06 12:50:29.115 | INFO     | __main__:parse_data:21 - processing page: 1445 MERCEDES 175
# 2021-03-06 12:50:29.690 | INFO     | __main__:parse_data:21 - processing page: 1446 NISSAN 184
# 2021-03-06 12:50:30.279 | INFO     | __main__:parse_data:21 - processing page: 1447 MITSUBISHI 119
# 2021-03-06 12:50:30.866 | INFO     | __main__:parse_data:21 - processing page: 1448 TOYOTA 164
# 2021-03-06 12:50:31.496 | INFO     | __main__:parse_data:21 - processing page: 1449 HONDA 48
# 2021-03-06 12:50:31.671 | INFO     | __main__:parse_data:21 - processing page: 1450 VOLKSWAGEN 185
# 2021-03-06 12:50:32.222 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_1450.csv, содержащий 1662 записей
# 2021-03-06 12:50:32.493 | INFO     | __main__:parse_data:21 - processing page: 1451 BMW 188
# 2021-03-06 12:50:33.073 | INFO     | __main__:parse_data:21 - processing page: 1452 SKODA 115
# 2021-03-06 12:50:34.021 | INFO     | __main__:parse_data:21 - processing page: 1453 MERCEDES 176
# 2021-03-06 12:50:34.729 | INFO     | __main__:parse_data:21 - processing page: 1454 NISSAN 185
# 2021-03-06 12:50:35.324 | INFO     | __main__:parse_data:21 - processing page: 1455 AUDI 144
# 2021-03-06 12:50:36.029 | INFO     | __main__:parse_data:21 - processing page: 1456 TOYOTA 165
# 2021-03-06 12:50:36.740 | INFO     | __main__:parse_data:21 - processing page: 1457 VOLKSWAGEN 186
# 2021-03-06 12:50:37.457 | INFO     | __main__:parse_data:21 - processing page: 1458 BMW 189
# 2021-03-06 12:50:38.120 | INFO     | __main__:parse_data:21 - processing page: 1459 MITSUBISHI 120
# 2021-03-06 12:50:38.760 | INFO     | __main__:parse_data:21 - processing page: 1460 LEXUS 35
# 2021-03-06 12:50:39.275 | INFO     | __main__:parse_data:21 - processing page: 1461 NISSAN 186
# 2021-03-06 12:50:39.893 | INFO     | __main__:parse_data:21 - processing page: 1462 MERCEDES 177
# 2021-03-06 12:50:40.577 | INFO     | __main__:parse_data:21 - processing page: 1463 SKODA 116
# 2021-03-06 12:50:41.199 | INFO     | __main__:parse_data:21 - processing page: 1464 AUDI 145
# 2021-03-06 12:50:41.729 | INFO     | __main__:parse_data:21 - processing page: 1465 TOYOTA 166
# 2021-03-06 12:50:42.327 | INFO     | __main__:parse_data:21 - processing page: 1466 VOLKSWAGEN 187
# 2021-03-06 12:50:42.995 | INFO     | __main__:parse_data:21 - processing page: 1467 BMW 190
# 2021-03-06 12:50:43.563 | INFO     | __main__:parse_data:21 - processing page: 1468 VOLVO 62
# 2021-03-06 12:50:43.760 | INFO     | __main__:parse_data:21 - processing page: 1469 NISSAN 187
# 2021-03-06 12:50:44.269 | INFO     | __main__:parse_data:21 - processing page: 1470 MERCEDES 178
# 2021-03-06 12:50:44.882 | INFO     | __main__:parse_data:21 - processing page: 1471 MITSUBISHI 121
# 2021-03-06 12:50:45.432 | INFO     | __main__:parse_data:21 - processing page: 1472 TOYOTA 167
# 2021-03-06 12:50:46.027 | INFO     | __main__:parse_data:21 - processing page: 1473 VOLKSWAGEN 188
# 2021-03-06 12:50:46.695 | INFO     | __main__:parse_data:21 - processing page: 1474 BMW 191
# 2021-03-06 12:50:47.368 | INFO     | __main__:parse_data:21 - processing page: 1475 AUDI 146
# 2021-03-06 12:50:47.981 | INFO     | __main__:parse_data:21 - processing page: 1476 SKODA 117
# 2021-03-06 12:50:48.941 | INFO     | __main__:parse_data:21 - processing page: 1477 NISSAN 188
# 2021-03-06 12:50:49.494 | INFO     | __main__:parse_data:21 - processing page: 1478 MERCEDES 179
# 2021-03-06 12:50:50.159 | INFO     | __main__:parse_data:21 - processing page: 1479 INFINITI 37
# 2021-03-06 12:50:50.343 | INFO     | __main__:parse_data:21 - processing page: 1480 HONDA 49
# 2021-03-06 12:50:50.540 | INFO     | __main__:parse_data:21 - processing page: 1481 VOLKSWAGEN 189
# 2021-03-06 12:50:51.290 | INFO     | __main__:parse_data:21 - processing page: 1482 BMW 192
# 2021-03-06 12:50:51.962 | INFO     | __main__:parse_data:21 - processing page: 1483 TOYOTA 168
# 2021-03-06 12:50:52.502 | INFO     | __main__:parse_data:21 - processing page: 1484 MITSUBISHI 122
# 2021-03-06 12:50:52.994 | INFO     | __main__:parse_data:21 - processing page: 1485 AUDI 147
# 2021-03-06 12:50:54.857 | INFO     | __main__:parse_data:21 - processing page: 1486 NISSAN 189
# 2021-03-06 12:50:55.470 | INFO     | __main__:parse_data:21 - processing page: 1487 MERCEDES 180
# 2021-03-06 12:50:55.980 | INFO     | __main__:parse_data:21 - processing page: 1488 SKODA 118
# 2021-03-06 12:50:56.688 | INFO     | __main__:parse_data:21 - processing page: 1489 VOLKSWAGEN 190
# 2021-03-06 12:50:57.283 | INFO     | __main__:parse_data:21 - processing page: 1490 BMW 193
# 2021-03-06 12:50:57.807 | INFO     | __main__:parse_data:21 - processing page: 1491 TOYOTA 169
# 2021-03-06 12:50:58.494 | INFO     | __main__:parse_data:21 - processing page: 1492 VOLVO 63
# 2021-03-06 12:50:58.643 | INFO     | __main__:parse_data:21 - processing page: 1493 NISSAN 190
# 2021-03-06 12:50:59.356 | INFO     | __main__:parse_data:21 - processing page: 1494 AUDI 148
# 2021-03-06 12:50:59.983 | INFO     | __main__:parse_data:21 - processing page: 1495 MERCEDES 181
# 2021-03-06 12:51:00.775 | INFO     | __main__:parse_data:21 - processing page: 1496 MITSUBISHI 123
# 2021-03-06 12:51:01.354 | INFO     | __main__:parse_data:21 - processing page: 1497 VOLKSWAGEN 191
# 2021-03-06 12:51:01.859 | INFO     | __main__:parse_data:21 - processing page: 1498 BMW 194
# 2021-03-06 12:51:02.457 | INFO     | __main__:parse_data:21 - processing page: 1499 TOYOTA 170
# 2021-03-06 12:51:03.084 | INFO     | __main__:parse_data:21 - processing page: 1500 SKODA 119
# 2021-03-06 12:51:03.812 | INFO     | __main__:write_to_csv:11 - writing train_folder\train_1500.csv, содержащий 1702 записей
# 2021-03-06 12:51:04.095 | INFO     | __main__:parse_data:21 - processing page: 1501 NISSAN 191
# 2021-03-06 12:51:04.559 | INFO     | __main__:parse_data:21 - processing page: 1502 LEXUS 36
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-b1160b2a6834> in <module>
# ----> 1 parse_data(2000,'train_folder',1,'json_folder')
#
# <ipython-input-27-394438edb016> in parse_data(n_pages, output_folder, save_json, json_folder)
#      21         logger.info(f'processing page: {page_num} {brand} {brand_stats[brand]}')
#      22         try:
# ---> 23             data_json = get_data_from_site(brand_stats[brand], brand)
#      24         except Exception as e:
#      25             logger.error(f"Error in parsing: {e}")
#
# <ipython-input-13-b46ea4394d3c> in get_data_from_site(pange_num, brand)
#       6     params = dict(category='cars', section="all", output_type="list", page=pange_num,
#       7                   catalog_filter=[{'mark': brand}], geo_id=[213], geo_radius=800)
# ----> 8     r = requests.post(base_url, json=params, headers=get_headers())
#       9     r.raise_for_status()
#      10     return r.json()
#
# ~\anaconda3\lib\site-packages\requests\api.py in post(url, data, json, **kwargs)
#     117     """
#     118
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#     120
#     121
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1849 entries, 0 to 1848
# Data columns (total 34 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   bodyType              1849 non-null   object
#  1   brand                 1849 non-null   object
#  2   car_url               1849 non-null   object
#  3   color                 1849 non-null   object
#  4   complectation_dict    1849 non-null   object
#  5   description           1847 non-null   object
#  6   engineDisplacement    1849 non-null   object
#  7   enginePower           1849 non-null   object
#  8   location              1849 non-null   object
#  9   equipment_dict        1849 non-null   object
#  10  fuelType              1849 non-null   object
#  11  image                 1849 non-null   object
#  12  mileage               1849 non-null   int64
#  13  modelDate             1849 non-null   int64
#  14  model_info            1849 non-null   object
#  15  model_name            1849 non-null   object
#  16  name                  1849 non-null   object
#  17  numberOfDoors         1849 non-null   int64
#  18  parsing_unixtime      1849 non-null   int64
#  19  priceCurrency         1849 non-null   object
#  20  productionDate        1849 non-null   int64
#  21  sell_id               1849 non-null   object
#  22  super_gen             1849 non-null   object
#  23  vehicleConfiguration  1849 non-null   object
#  24  vehicleTransmission   1849 non-null   object
#  25  vendor                1849 non-null   object
#  26  Владельцы             1430 non-null   float64
#  27  Владение              81 non-null     object
#  28  ПТС                   1830 non-null   object
#  29  Привод                1849 non-null   object
#  30  Руль                  1849 non-null   object
#  31  Состояние             1849 non-null   bool
#  32  Таможня               1849 non-null   bool
#  33  price                 1849 non-null   int64
# dtypes: bool(2), float64(1), int64(6), object(25)
# memory usage: 466.0+ KB
